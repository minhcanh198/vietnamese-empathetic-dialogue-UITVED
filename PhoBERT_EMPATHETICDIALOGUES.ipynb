# %% [markdown]
# #CÀI ĐẶT THƯ VIỆN

# %%
# %cd '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues'
# !pip install fairseq
# !pip install transformers
# !pip install fastBPE

# %cd ParlAI/
# !python setup.py develop
# %cd ../
# Out:
# /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues
# ...
#      |████████████████████████████████| 307kB 4.4MB/s
# ...
#      |████████████████████████████████| 51kB 5.9MB/s
# ...
#   Created wheel for fairseq: filename=fairseq-0.9.0-cp36-cp36m-linux_x86_64.whl size=2046458 sha256=e38afd65306da98251c7a31cdbf8f69ce6329d2fa2599f6fe7be8c2b2361ee43
#   Stored in directory: /root/.cache/pip/wheels/37/3e/1b/0fa30695dcba41e4b0088067fa40f3328d1e8ee78c22cd4766
# Successfully built fairseq
# ...
#      |████████████████████████████████| 778kB 4.4MB/s
# ...
#      |████████████████████████████████| 3.0MB 20.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 42.6MB/s
# ...
#      |████████████████████████████████| 890kB 55.9MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=2d66360dabbe85e2bf766c4f1566748b832964809c4223384ad14b86c68b88bb
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# ...

# %% [markdown]
# #PhoBert Model

# %%
# !python retrieval_train.py \
--batch-size 52 \
--bert-dim 300 \
--cuda \
--no-shuffle \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound' \
--learning-rate 6e-5 \
--max-hist-len 4 \
--model bert \
--model-dir '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models' \
--model-name PhoBERT_ved_auto_non_use_token \
--num-epochs 10 \
--optimizer adamax \
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-20 14:41:41.953238: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# ============FINETUNE===========

# %%
# !python retrieval_train.py \
--batch-size 52 \
--bert-dim 300 \
--cuda \
--no-shuffle \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/trong-16062020-vietnamese-compound' \
--learning-rate 1e-5 \
--max-hist-len 4 \
--model bert \
--model-dir '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models' \
--load-checkpoint '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_manual_batch52.mdl' \
--model-name PhoBERT_ved_manual_batch52_finetune \
--num-epochs 10 \
--optimizer adamax \
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-21 13:13:20.267215: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# EVALUATION

# %%
# --empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/trong-16062020-ed' \
# !python retrieval_train.py \
--cuda \
--batch-size 52 \
--bert-dim 300 \
--no-shuffle \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--max-hist-len 4 \
--model bert \
--model-dir '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models' \
--model-name PhoBERT_ved_auto_batch52_128_finetune \
--optimizer adamax \
--pretrained '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl' \
--reactonly
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-25 02:16:50.875792: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# BLEU SCORE

# %%
# BLEU (EmpatheticDialogues context/candidates)
# !python retrieval_eval_bleu.py \
--empchat-cands \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/trong-16062020-vietnamese-compound' \
--max-hist-len 4 \
--model '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl' \
--name "PhoBERT_ved_auto_batch52_128_finetune" \
--output-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/bleu-output' \
--reactonly \
--task empchat
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-21 15:11:49.278791: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 08/21/2020 03:11:51 PM: [ CUDA enabled (GPU -1) ]
# 08/21/2020 03:11:51 PM: [ Loading model /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl ]
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 08/21/2020 03:12:58 PM: [ loading configuration file /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/config.json ]
# 08/21/2020 03:12:58 PM: [ Model config RobertaConfig {
#   "architectures": [
# ...

# %% [markdown]
# #PHOBERRT + EMOPREPEND-1

# %%
# !pip install fasttext
# Out:
# ...
#      |████████████████████████████████| 71kB 5.0MB/s
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp36-cp36m-linux_x86_64.whl size=3016304 sha256=ac4544a03b9f71530f37fbb6b8650baf707681582c978aa054dfb40770749cd7
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
# Successfully built fasttext
# ...

# %%
import fasttext as fasttext_module
ftmodel = fasttext_module.FastText.load_model('/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Fasttext/fastText_ved_auto_2108_v2.bin')

# %%
lable, _ = ftmodel.predict('Tôi đã rất vui và buồn ngủ quá đi thôi', 1)

# %%
r = lable[0]
print(r)
print("_".join(r.split('_')[-2:]))
# Out:
# __label__ghê_tởm
# ghê_tởm

# %% [markdown]
# ========TRAIN========

# %%
# !python retrieval_train.py \
--batch-size 52 \
--bert-dim 300 \
--cuda \
--no-shuffle \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound' \
--learning-rate 6e-5 \
--max-hist-len 4 \
--model bert \
--model-dir '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models' \
--model-name PhoBert_emo_auto \
--num-epochs 10 \
--optimizer adamax \
--fasttext 1 \
--fasttext-path '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Fasttext/fastText_ved_auto_2108_v2.bin' \
--fasttext-type emo
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-21 05:54:25.400841: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# ========FINETUNE========

# %%
# !python retrieval_train.py \
--batch-size 52 \
--bert-dim 300 \
--cuda \
--no-shuffle \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound' \
--learning-rate 1e-5 \
--max-hist-len 4 \
--model bert \
--model-dir '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models' \
--load-checkpoint '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBert_emo_manual.mdl' \
--model-name PhoBert_emo_manual \
--num-epochs 20 \
--optimizer adamax \
--fasttext 1 \
--fasttext-path '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Fasttext/fastText_ved_auto_2108_v2.bin' \
--fasttext-type emo
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-21 04:58:52.216240: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# Computing P@ of bert

# %%
# computing P@ of bert
# !python retrieval_train.py \
--batch-size 52 \
--bert-dim 300 \
--cuda \
--dataset-name empchat \
--dict-max-words 250000 \
--display-iter 100 \
--embeddings None \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound' \
--max-hist-len 4 \
--model bert \
--model-dir models \
--model-name PhoBert_emo_auto \
--optimizer adamax \
--pretrained "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBert_emo_auto.mdl" \
--reactonly \
--fasttext 1 \
--fasttext-path "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Fasttext/fastText_ved_auto_2108_v2.bin" \
--fasttext-type emo
# Out:
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Loading codes from /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# 2020-08-21 11:56:28.066781: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# CALCULATE BLEU

# %%
# BLEU (EmpatheticDialogues context/candidates)
# !python retrieval_eval_bleu.py \
--empchat-cands \
--empchat-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound' \
--max-hist-len 4 \
--model '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl' \
--name PhoBERT_ved_auto_batch52_128_finetune \
--output-folder '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/bleu-output' \
--reactonly \
--task empchat \
--fasttext 1 \
--fasttext-path '/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Fasttext/fastText_ved_auto_2108_v2.bin' \
--fasttext-type emo
# Out:
# python3: can't open file 'retrieval_eval_bleu.py': [Errno 2] No such file or directory

# %% [markdown]
# #GENERATE RESPONSES

# %%
import logging
import os

import torch
from fairseq import bleu
from tqdm import tqdm

from empchat.datasets.dailydialog import DDDataset
from empchat.datasets.empchat import EmpDataset
from empchat.datasets.reddit import RedditDataset
from empchat.datasets.parlai_dictionary import ParlAIDictionary
from empchat.datasets.tokens import tokenize, PAD_TOKEN, START_OF_COMMENT, UNK_TOKEN
from empchat.models import load as load_model, score_candidates
from empchat.util import get_opt


logger = logging.getLogger()
logger.setLevel(logging.INFO)
fmt = logging.Formatter("%(asctime)s: [ %(message)s ]", "%m/%d/%Y %I:%M:%S %p")
console = logging.StreamHandler()
console.setFormatter(fmt)
logger.handlers = []
logger.addHandler(console)

# ------------------------------------------------------------------------------
# Commandline arguments & init
# ------------------------------------------------------------------------------

class Args():
    def __init__(self):
        self.bleu_dict = None
        self.candidates = None
        self.dailydialog_cands = False
        self.dailydialog_folder = False
        self.empchat_cands = True
        # self.empchat_folder = "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/uit-ved-auto-compound"
        self.empchat_folder = "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/empatheticdialogues/trong-16062020-vietnamese-compound"
        self.fasttext = None
        self.fasttext_path = None
        self.fasttext_type = None
        self.gpu = -1 
        self.max_cand_length = 20
        self.max_hist_len = 4
        self.model = "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl" 
        self.n_candidates = int(1e6)
        self.name = "PhoBERT_ved_auto_batch52_128_finetune"
        self.no_cuda = False
        self.normalize_cands = False
        self.output_folder = "/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/Response a context"
        self.reactonly = True
        self.reddit_cands = False
        self.reddit_folder = False
        self.save_candidates = False
        self.task = "empchat"
           
args = Args()

args.cuda = not args.no_cuda and torch.cuda.is_available()
if args.cuda:
    torch.cuda.set_device(args.gpu)
    logger.info(f"CUDA enabled (GPU {args.gpu:d})")
else:
    logger.info("Running on CPU only.")
if args.fasttext is not None:
    args.max_cand_length += args.fasttext
net, net_dictionary = load_model(args.model, get_opt(existing_opt=args))
if "bert_tokenizer" in net_dictionary:
    if args.task == "dailydialog":
        raise NotImplementedError("BERT model currently incompatible with DailyDialog!")
if args.bleu_dict is not None:
    _, bleu_dictionary = load_model(args.bleu_dict, get_opt(existing_opt=args))
else:
    bleu_dictionary = net_dictionary
paramnum = 0
trainable = 0
for parameter in net.parameters():
    if parameter.requires_grad:
        trainable += parameter.numel()
    paramnum += parameter.numel()
 
NET_PAD_IDX = net_dictionary["words"][PAD_TOKEN]
NET_UNK_IDX = net_dictionary["words"][UNK_TOKEN]
BLEU_PAD_IDX = bleu_dictionary["words"][PAD_TOKEN]
BLEU_UNK_IDX = bleu_dictionary["words"][UNK_TOKEN]
BLEU_EOS_IDX = bleu_dictionary["words"][START_OF_COMMENT]
args.cuda = not args.no_cuda and torch.cuda.is_available()
if args.cuda:
    torch.cuda.set_device(args.gpu)
    logger.info(f"CUDA enabled (GPU {args.gpu:d})")
else:
    logger.info("Running on CPU only.")
actual_ct = [0, 0, 0]
if args.cuda:
    net = torch.nn.DataParallel(net)
    net.cuda()
net.eval()


def pad(items):
    max_len = max(len(i) for i in items)
    tensor = torch.LongTensor(len(items), max_len).fill_(NET_PAD_IDX)
    for i, sentence in enumerate(items):
        tensor[i, : sentence.size(0)] = sentence
    return tensor


def build_candidates(
    max_cand_length, n_cands=int(1e7), rm_duplicates=True, rm_starting_gt=True
):
    global actual_ct
    global args
    tensor = torch.LongTensor(n_cands, max_cand_length).fill_(NET_PAD_IDX)
    i = 0
    chunk = 422
    if "bert_tokenizer" in net_dictionary:
        gt_tokens = torch.LongTensor(
            net_dictionary["bert_tokenizer"].convert_tokens_to_ids(["&", "g", "##t"])
        )
    else:
        gt_index = net_dictionary["words"]["&gt"]
        lt_index = net_dictionary["words"]["&lt"]
    unk_index = net_dictionary["words"]["<UNK>"]
    n_duplicates = n_start_gt = 0
    if rm_duplicates:
        all_sent = set()

    def _has_lts(sentence_) -> bool:
        if "bert_tokenizer" in net_dictionary:
            tokens = net_dictionary["bert_tokenizer"].convert_ids_to_tokens(
                sentence_.tolist()
            )
            return "& l ##t" in " ".join(tokens)
        else:
            return torch.sum(sentence_ == lt_index).gt(0)

    def _starts_with_gt(sentence_) -> bool:
        if "bert_tokenizer" in net_dictionary:
            if sentence_.size(0) < 3:
                return False
            else:
                return torch.eq(sentence_[:3], gt_tokens).all()
        else:
            return sentence_[0].item == gt_index

    parlai_dict = ParlAIDictionary.create_from_reddit_style(net_dictionary)
    if args.empchat_cands:
        dataset = EmpDataset(
            "train",
            parlai_dict,
            data_folder=args.empchat_folder,
            reactonly=True,
            fasttext=args.fasttext,
            fasttext_type=args.fasttext_type,
            fasttext_path=args.fasttext_path,
        )
        sample_index = range(len(dataset))
        for data_idx in sample_index:
            _context, sentence, _ = dataset[data_idx]
            sent_length = sentence.size(0)
            if torch.sum(sentence == unk_index).gt(0):
                continue
            if _has_lts(sentence):
                continue
            if sent_length <= max_cand_length:
                if _starts_with_gt(sentence) and rm_starting_gt:
                    n_start_gt += 1
                    continue
                if rm_duplicates:
                    tuple_sent = tuple(sentence.numpy())
                    if tuple_sent in all_sent:
                        n_duplicates += 1
                        continue
                    all_sent.add(tuple_sent)
                tensor[i, : sentence.size(0)] = sentence
                i += 1
                if i >= n_cands:
                    break
    breakpoint_ = i
    actual_ct[1] = i
    bp2 = i
    actual_ct[2] = i - breakpoint_
    actual_ct[0] = i - bp2
    logging.info(
        f"Loaded {i} candidates, {n_start_gt} start with >, {n_duplicates} duplicates"
    )
    args.n_candidates = i
    return tensor[:i, :], breakpoint_, bp2


def embed_candidates(candidates):
    out_tensor = None
    i = 0
    ch = candidates.split(1024, dim=0)
    for chunk in tqdm(range(len(ch))):
        _, encoded_cand = net(None, ch[chunk])
        if out_tensor is None:
            out_tensor = torch.FloatTensor(candidates.size(0), encoded_cand.size(1))
            if args.cuda:
                out_tensor = out_tensor.cuda()
        if args.normalize_cands:
            encoded_cand /= encoded_cand.norm(2, dim=1, keepdim=True)
        batch_size = encoded_cand.size(0)
        out_tensor[i : i + batch_size] = encoded_cand
        i += batch_size
    return out_tensor


def get_token_tensor(sentence):
    words = net_dictionary["words"]
    tokenized = tokenize(sentence, split_sep=None)
    return torch.LongTensor([words.get(w, NET_UNK_IDX) for w in tokenized])

if args.candidates:
    fixed_candidates = torch.load(args.candidates)
    if args.n_candidates < fixed_candidates.size(0):
        logging.warning(
            f"Keeping only {args.n_candidates} / {fixed_candidates.size(0)} candidates"
        )
        fixed_candidates = fixed_candidates[: args.n_candidates]
else:
    fixed_candidates, breakingpt, breakingpt2 = build_candidates(
        args.max_cand_length, args.n_candidates
    )
if args.cuda:
    fixed_candidates = fixed_candidates.cuda(non_blocking=True)
logging.warning("Embedding candidates")
with torch.no_grad():
    cand_embs = embed_candidates(fixed_candidates)
logging.warning("Done with candidates")
# Out:
# 08/27/2020 05:44:56 AM: [ CUDA enabled (GPU -1) ]
# 08/27/2020 05:44:56 AM: [ Loading model /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/PhoBERT_ved_auto_batch52_128_finetune.mdl ]
# 08/27/2020 05:45:35 AM: [ loading configuration file /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/config.json ]
# 08/27/2020 05:45:35 AM: [ Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "eos_token_ids": 0,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 258,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
# ...

# %%
import os
import re
import argparse
import torch
from torch.utils.data import Dataset

from empchat.datasets.parlai_dictionary import ParlAIDictionary
from empchat.datasets.tokens import get_bert_token_mapping, tokenize

from fairseq.data.encoders.fastbpe import fastBPE
from fairseq.data import Dictionary

parser = argparse.ArgumentParser()
parser.add_argument('--bpe-codes',
                    default="/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes",
                    type=str)
BPE_args = parser.parse_args([])
bpe = fastBPE(BPE_args)

class PhoBertTokenizer(object):
    def __init__(
        self,
    ):
        self.vocab = Dictionary()
        self.vocab.add_from_file("/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/dict.txt")
        
    def tokenize(self, inp_string):
        return bpe.encode(inp_string).split(" ")

    def convert_tokens_to_ids(self, tokens):
        return self.vocab.encode_line(" ".join(tokens), append_eos=False, add_if_not_exist=False).long().tolist()

    def convert_ids_to_tokens(self, ids):
      return self.vocab.string(torch.tensor([ids], dtype=torch.long))

def txt2vec(dic, text, fasttext_type=None):
    if hasattr(dic, "bert_tokenizer"):
        orig_mapping = get_bert_token_mapping(fasttext_type)
        mapping = dict((re.escape(k), v) for k, v in orig_mapping.items())
        pattern = re.compile("|".join(mapping.keys()))
        cleaned_text = pattern.sub(lambda m: mapping[re.escape(m.group(0))], text)
        tokenized_text = dic.bert_tokenizer.tokenize(cleaned_text)
        tokenized_text = ['<s>'] + tokenized_text
        return dic.bert_tokenizer.convert_tokens_to_ids(tokenized_text)
    elif type(dic) is ParlAIDictionary:
        return dic.txt2vec(text)
    else:
        return [dic.index(token) for token in tokenize(text)]


def sentence_to_tensor(dic, sentence, maxlen=None, fasttext_type=None):
    """
    simply convert a sentence to a torch tensor.
    """
    indexes = txt2vec(dic, sentence, fasttext_type)
    if maxlen is not None and maxlen <= len(indexes):
        indexes = indexes[: maxlen - 1]
    if type(dic) is ParlAIDictionary:
        return torch.LongTensor(indexes)
    else:
        indexes.append(dic.eos())
        return torch.LongTensor(indexes)

class EmpOne(Dataset):
    def __init__(
        self,
        splitname,
        dic,
        data_folder,
        maxlen=100,
        reactonly=False,
        fasttext=None,
        fasttext_type=None,
        fasttext_path=None,
    ):
        topicmap = {
            "alt.atheism": "atheism",
            "comp.graphics": "graphics",
            "comp.os.ms-windows.misc": "windows",
            "comp.sys.ibm.pc.hardware": "pc",
            "comp.sys.mac.hardware": "mac",
            "comp.windows.x": "x",
            "misc.forsale": "sale",
            "rec.autos": "autos",
            "rec.motorcycles": "motorcycles",
            "rec.sport.baseball": "baseball",
            "rec.sport.hockey": "hockey",
            "sci.crypt": "cryptography",
            "sci.electronics": "electronics",
            "sci.med": "medicine",
            "sci.space": "space",
            "soc.religion.christian": "christian",
            "talk.politics.guns": "guns",
            "talk.politics.mideast": "mideast",
            "talk.politics.misc": "politics",
            "talk.religion.misc": "religion",
            "windows.misc": "windows",
        }
        # ^ 'windows.misc' was included for compatibility because the code below
        # splits topics on hyphens
        
        df = open(os.path.join( args.empchat_folder, f"{splitname}.csv")).readlines()

        newmaxlen = maxlen
        # self.max_hist_len = history_len
        if fasttext is not None:
            import fasttext as fasttext_module

            assert fasttext_type is not None and fasttext_path is not None
            self.ftmodel = fasttext_module.FastText.load_model(fasttext_path)
            newmaxlen += fasttext
            maxlen += fasttext
            if hasattr(dic, "bert_tokenizer"):
                new_tokenizer = PhoBertTokenizer()
                assert new_tokenizer.vocab.symbols == dic.bert_tokenizer.vocab.symbols
                # ^ This should fail if the original tokenizer was not from the
                # 'bert-base-cased' model
                dic.bert_tokenizer = new_tokenizer
        self.reactonly = reactonly
        self.data = []
        self.ids = []
        
        sparts = df[1].strip().split(",")
        prevsent = sparts[5].replace("_comma_", " ,")
        if fasttext is not None:
            gettop, _ = self.ftmodel.predict(
                prevsent, k=fasttext
            )
            for f in gettop:
                prevsent = (
                    topicmap.get(
                        f.split("_")[-1].split("-")[-1],
                        f.split("_")[-1].split("-")[-1],
                    )
                    + " "
                    + prev_str
                )
        contextt = sentence_to_tensor(
            dic, prevsent, fasttext_type=fasttext_type
        )[:newmaxlen]
        sent = sparts[5].replace("_comma_", " ,")
        if fasttext is not None:
            gettop, _ = self.ftmodel.predict(sent, k=fasttext)
            for f in gettop:
                sent = (
                    topicmap.get(
                        f.split("_")[-1].split("-")[-1],
                        f.split("_")[-1].split("-")[-1],
                    )
                    + " "
                    + sent
                )
        label = sentence_to_tensor(dic, sent, fasttext_type=fasttext_type)[
            :maxlen
        ]
        lbl_min = torch.LongTensor([[dic[sparts[2]]]])
        self.data.append((contextt, label, lbl_min))
        self.ids.append((sparts[0], sparts[1]))
          

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]

    def getid(self, index):
        return self.ids[index]

# %%
# !pip install underthesea
from underthesea import word_tokenize
import pdb

def stringify(tensor):
    iwords = net_dictionary["iwords"]
    assert tensor.squeeze().dim() == 1, "Wrong tensor size!"
    return " ".join(
        iwords[i] for i in tensor.squeeze().cpu().numpy() if i != NET_PAD_IDX
    ).replace("@@ ", "").replace('_',' ').replace('<s>','')
    # Remove any BPE tokenization

def predict(context, top_n=5, normalize=False):
    """
    returns a list of top_n tuples ("sentence", "score")
    """
    with torch.no_grad():
        context = context.unsqueeze(0)
        candidates = fixed_candidates
        if args.cuda:
            context = context.cuda(non_blocking=True)
        ctx, _ = net(context, None)
        scores, index = score_candidates(ctx, cand_embs, top_n, normalize)
        response = []
        outputs = []
        for i, (score, index) in enumerate(zip(scores.squeeze(0), index.squeeze(0)), 1):
            response.append((stringify(candidates[index]), float(score)))
            if index < breakingpt:
                outputs.append("EmpChat")
            elif index < breakingpt2:
                outputs.append("DailyDialog")
            else:
                outputs.append("Reddit")
        return response, outputs


def get_response(split):
    if (args.origin_utterance == 'X' or args.origin_utterance == 'x'):
        args.history = []
        print('args.history: ', args.history)
        return "Tạm biệt và hẹn gặp lại nhé <3 <3 <3"
    else:
      max_his_length = 4
      args.origin_utterance = word_tokenize(args.origin_utterance, format="text")
      args.history.append(args.origin_utterance)
      print('args.history: ', args.history[-max_his_length:])
      args.utterance = " <SOC> ".join(args.history[-max_his_length:])
      with open( args.empchat_folder + "/one_sentence.csv", "w+") as wf:
          wf.write("conv_id,utterance_idx,context,prompt,speaker_idx,utterance,selfeval,tags\n")
          wf.write(" hit:0_conv:0,2,,,,{},,\n".format(args.utterance.replace(",", "_comma_")))

      """
      Print BLEU scores and output contexts and retrieved responses.
      """
      source_ct = [0, 0, 0]
      net_parlai_dict = ParlAIDictionary.create_from_reddit_style(net_dictionary)
      bleu_parlai_dict = ParlAIDictionary.create_from_reddit_style(bleu_dictionary)
      scorer = bleu.Scorer(BLEU_PAD_IDX, BLEU_EOS_IDX, BLEU_UNK_IDX)
      outf = open( args.output_folder + "/retrieved_split_" + args.name + "_" + split + ".txt", "w")

      def _get_dataset(reddit_dict, parlai_dict):
          
          if args.task == "empchat":
              return EmpOne(
                  split,
                  parlai_dict,
                  data_folder=args.empchat_folder,
                  reactonly=args.reactonly,
                  fasttext=args.fasttext,
                  fasttext_type=args.fasttext_type,
                  fasttext_path=args.fasttext_path,
              )
          else:
              raise ValueError("Task unrecognized!")

      net_dataset = _get_dataset(net_dictionary, net_parlai_dict)
      bleu_dataset = _get_dataset(bleu_dictionary, bleu_parlai_dict)
      sample_index = range(len(bleu_dataset))
      for data_idx in sample_index:
          net_context, _ = net_dataset[data_idx][:2]
          bleu_context, bleu_sentence = bleu_dataset[data_idx][:2]
          target_tokens = bleu_sentence
          if args.fasttext is not None:
              target_tokens = target_tokens[args.fasttext :]
          context = bleu_parlai_dict.vec2txt(bleu_context.numpy().tolist())
          responses, sources = predict(net_context)
          response = responses[0][0]
          
          args.history.append(word_tokenize(response, format='text'))
          source = sources[0]
          if source == "Reddit":
              source_ct[0] += 1
          elif source == "EmpChat":
              source_ct[1] += 1
          else:
              sourice_ct[2] += 1
          if args.task == "empchat":
              cid, sid = bleu_dataset.getid(data_idx)
          else:
              cid = sid = -1
              # This is a hack, because the other datasets have no .getid() method
          if args.fasttext is not None:
              response = " ".join(response.split()[args.fasttext :])
          outf.write("\t".join([str(cid), str(sid), context, response, source]) + "\n")
          
          return response
args.history = []
# Out:
# ...
#      |████████████████████████████████| 7.1MB 3.5MB/s
# ...
#      |████████████████████████████████| 460kB 47.3MB/s
# ...
#      |████████████████████████████████| 1.5MB 47.4MB/s
# ...
#      |████████████████████████████████| 757kB 51.0MB/s
# ...
#      |████████████████████████████████| 286kB 52.7MB/s
# ...
#      |████████████████████████████████| 5.4MB 17.9MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449908 sha256=a64fe46b53e4632ae026816427d47f0109a39a7e9c5b350f21231353d7f66c1f
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# ...
#   Created wheel for clint: filename=clint-0.5.1-cp36-none-any.whl size=34448 sha256=95ad457db622d5011a2f46a1afbbe8a06c00968777440dff875431e770fb4768
#   Stored in directory: /root/.cache/pip/wheels/4f/e9/45/223565e5b1a4b09e12c6de6f8ba7c2c0e9127dec17cf830f83
# ...

# %%
args.origin_utterance = "x"
res = get_response("one_sentence")
print('res:', res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f41b96e1f5c> in <module>()
# ----> 1 args.origin_utterance = "x"
#       2 res = get_response("one_sentence")
#       3 print('res:', res)
#
# NameError: name 'args' is not defined

# %%
# !pip install underthesea

# %% [markdown]
# # Empathetic Chatbot On Messenger

# %%
# %cd /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues
# Out:
# /content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues

# %%
# !ls

# %%
# !pip install pymessenger

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip


# get_ipython().system_raw('tensorboard --logdir /content/trainingdata/objectdetection/ckpt_output/trainingImatges/ --host 0.0.0.0 --port 6006 &')
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 5000 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
 "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://2e040df4ab9d.ngrok.io

# %%
# !pip install pyngrok
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.10-cp36-none-any.whl size=16378 sha256=d3af46379c042e621f233f3da84eaa01f2376153f64f753a7c4943dee164a4d0
#   Stored in directory: /root/.cache/pip/wheels/0d/7f/06/e8079dd6f80eb6683fac47c4e1cb720b61cd82d6e4c13d87a5
# Successfully built pyngrok
# ...

# %%
get_ipython().system_raw('./ngrok http 5000 &')

! curl -s http://localhost:4040/api/tunnels | python3 -c \
 "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

from flask import Flask, request
import requests
import sys
import os
import json
# from TalkToBot import Talk_To_Bot
import random
from pymessenger.bot import Bot

VERIFY_TOKEN = 'canhcs'
PAGE_ACCESS_TOKEN = 'EAAIRlhdt7CUBAGHoZARMNw9kxVgM1SqbVIAKpuOo562IfYtIhaUpMckKopZAPX0Po59CDyVveyRbBmeVO6cHqJEZAb3EyZBCupS0t92TxkNwyXAKYE12ZAx7sIN1TkE9CAQHyDXMqMsnShUgzwzEIjHYDQVXZB5nIKidcFSNhArRi1bjUZCbI8LuK0klfnT62IZD'

app = Flask(__name__)

bot = Bot(PAGE_ACCESS_TOKEN)
#We will receive messages that Facebook sends our bot at this endpoint 
@app.route("/", methods=['GET', 'POST'])
def receive_message():
    if request.method == 'GET':
        """Before allowing people to message your bot, Facebook has implemented a verify token
        that confirms all requests that your bot receives came from Facebook.""" 
        token_sent = request.args.get("hub.verify_token")
        return verify_fb_token(token_sent)
    #if the request was not get, it must be POST and we can just proceed with sending a message back to user
    else:
        # get whatever message a user sent the bot
        output = request.get_json()
        #  print('output:', output)
        for event in output['entry']:
          # print('event: ', event)
          messaging = event['messaging']
          for message in messaging:
            if message.get('message'):
                #Facebook Messenger ID for user so we know where to send response back to
                recipient_id = message['sender']['id']
                # print('recipient_id', type(recipient_id))
                if recipient_id == '2588748237829496':
                  if message['message'].get('text'):
                      response_sent_text = get_message(message['message'].get('text'))
                      send_message(recipient_id, response_sent_text)
                      return "Message Processed"
                  #if user sends us a GIF, photo,video, or any other non-text item
                  if message['message'].get('attachments'):
                      response_sent_nontext = "Thử lại nhé!"
                      send_message(recipient_id, response_sent_nontext)
                      return "Message Processed"
    return "Message Not Processed"


def verify_fb_token(token_sent):
    #take token sent by facebook and verify it matches the verify token you sent
    #if they match, allow the request, else return an error 
    if token_sent == VERIFY_TOKEN:
        return request.args.get("hub.challenge")
    return 'Invalid verification token'


#chooses a random message to send to the user
def get_message(message):
    print('message: ', message)
    args.origin_utterance = message
    return get_response("one_sentence")

#uses PyMessenger to send response to user
def send_message(recipient_id, response):
    #sends user the text message provided via input response parameter
    bot.send_text_message(recipient_id, response)
    return "success"

if __name__ == "__main__":
    port = int(os.environ.get("PORT", 5000))
    app.run(host='127.0.0.1', port=port)
# Out:
# https://2e040df4ab9d.ngrok.io
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# 08/27/2020 06:21:01 AM: [  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit) ]
# 08/27/2020 06:21:18 AM: [ 127.0.0.1 - - [27/Aug/2020 06:21:18] "GET /?hub.mode=subscribe&hub.challenge=885376524&hub.verify_token=canhcs HTTP/1.1" 200 - ]
# message:  x
# args.history:  []
# 08/27/2020 06:22:21 AM: [ 127.0.0.1 - - [27/Aug/2020 06:22:21] "POST / HTTP/1.1" 200 - ]
# 08/27/2020 06:22:21 AM: [ 127.0.0.1 - - [27/Aug/2020 06:22:21] "POST / HTTP/1.1" 200 - ]
# 08/27/2020 06:22:21 AM: [ 127.0.0.1 - - [27/Aug/2020 06:22:21] "POST / HTTP/1.1" 200 - ]
# 08/27/2020 06:22:21 AM: [ 127.0.0.1 - - [27/Aug/2020 06:22:21] "POST / HTTP/1.1" 200 - ]
# 08/27/2020 06:22:21 AM: [ 127.0.0.1 - - [27/Aug/2020 06:22:21] "POST / HTTP/1.1" 200 - ]
# ...

# %% [markdown]
# #TEST LIBRARY

# %% [markdown]
# Install lib

# %%
# !pip install underthesea
# !pip install transformers
# !pip install fastBPE
# !pip install fairseq
# !pip install pytorch-pretrained-bert==0.5.1
# !pip install fastText
# Out:
# ...
#      |████████████████████████████████| 7.1MB 2.6MB/s
# ...
#      |████████████████████████████████| 460kB 34.5MB/s
# ...
#      |████████████████████████████████| 1.5MB 43.1MB/s
# ...
#      |████████████████████████████████| 757kB 40.4MB/s
# ...
#      |████████████████████████████████| 286kB 39.8MB/s
# ...
#      |████████████████████████████████| 5.4MB 42.4MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449904 sha256=ba82a5f37af49bdd1e3a9e48a864bb494d66722f69ecafa997a45421c9ca92e1
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# ...
#   Created wheel for clint: filename=clint-0.5.1-cp36-none-any.whl size=34449 sha256=d849858ad09905130c66535aa289cf0f6051741c7c22b9009484173e9b20628b
#   Stored in directory: /root/.cache/pip/wheels/4f/e9/45/223565e5b1a4b09e12c6de6f8ba7c2c0e9127dec17cf830f83
# ...

# %%
# !pip install underthesea
# Out:
# ...
#      |████████████████████████████████| 7.1MB 2.4MB/s
# ...
#      |████████████████████████████████| 1.5MB 43.7MB/s
# ...
#      |████████████████████████████████| 460kB 33.5MB/s
# ...
#      |████████████████████████████████| 757kB 40.7MB/s
# ...
#      |████████████████████████████████| 286kB 43.7MB/s
# ...
#      |████████████████████████████████| 5.4MB 14.8MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449906 sha256=703e235ab210e6149bbfa83eb710bed83d8ca8d476d868720dd94c0b775b255a
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# ...
#   Created wheel for clint: filename=clint-0.5.1-cp36-none-any.whl size=34449 sha256=f14cf4ef93830d1990cc6cecc664d1c94f067873603de072a67898883ed01389
#   Stored in directory: /root/.cache/pip/wheels/4f/e9/45/223565e5b1a4b09e12c6de6f8ba7c2c0e9127dec17cf830f83
# ...

# %%
from underthesea import word_tokenize

sentence = "thế thì"
print(word_tokenize(sentence, format="text"))
# Out:
# thế thì

# %% [markdown]
# Test Fastext model

# %%
import fasttext as fasttext_module

ftmodel = fasttext_module.FastText.load_model('/content/drive/My Drive/EMPATHETICDIALOGUES/EmpatheticDialogues/models/fasttext_empathetic_dialogues.mdl')

# %% [markdown]
# TEST LOAD MODEL

# %%
import torch
import torch.nn as nn

saved_params = torch.load('/content/drive/My Drive/PhoBERT_EMPATHETICDIALOGUES/EmpatheticDialogues/models/phoBert_vietnamese_19062020_1619_pretrained.mdl', map_location=lambda storage, loc: storage)

# %%
print(len(saved_params))
# print((saved_params['word_dict']['words']['']))
# for word in saved_params['word_dict']['words']:
#   print(word) 
print('============')
for params in saved_params:
  print(params)
# Out:
# 3
# ...
# state_dict
# opt
# optim_dict

# %% [markdown]
# TEST MULTILINGUAL BERT

# %%
 from pytorch_pretrained_bert import BertTokenizer
 new_tokenizer = BertTokenizer.from_pretrained(
                    "bert-base-multilingual-cased",
                    do_lower_case=False,
                    never_split=(
                        ["[CLS]", "[MASK]"]
                    ),
                )
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# 100%|██████████| 995526/995526 [00:00<00:00, 1835946.35B/s]

# %%
print(new_tokenizer.tokenize('tôi đi học'))
# Out:
# ['tôi', 'đi', 'học']

# %%
# !python
# Out:
# Python 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>>

# %% [markdown]
# TEST PHOBERT MODEL

# %%
# !pip install underthesea
from underthesea import word_tokenize
from transformers import *
import argparse
import collections
import torch
from fairseq.data.encoders.fastbpe import fastBPE
from fairseq.data import Dictionary
import pdb
class PhoBertTokenizer(object):
    def __init__(
        self,
       
    ):
        self.vocab = Dictionary()
        self.vocab.add_from_file("/content/drive/My Drive/EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/dict.txt")
    def tokenize(self, inp_string):
        parser = argparse.ArgumentParser()
        parser.add_argument('--bpe-codes',
                            default="/content/drive/My Drive/EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/bpe.codes",
                            type=str)
        args = parser.parse_args([])
        bpe = fastBPE(args)
        return bpe.encode(inp_string).split(" ")

    def convert_tokens_to_ids(self, tokens):
        return self.vocab.encode_line(" ".join(tokens), append_eos=False, add_if_not_exist=False).long().tolist()

    def convert_ids_to_tokens(self, ids):
      return self.vocab.string(torch.tensor([ids], dtype=torch.long))
# pdb.set_trace()
phobert = PhoBertTokenizer()
# bertMultitokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case = False)

# %%
print(phobert.vocab.symbols)
# sentence = 'Vâng . Con tôi rất thích chúng . Dù_sao tôi cũng luôn muốn có một con mèo_comma_'
# sentence = sentence.replace('_comma_', ' ,')
# print(sentence)
# tokens = phobert.tokenize(sentence)

# toId = phobert.convert_tokens_to_ids(tokens)
# print(tokens)
# Out:
# ['<s>', '<pad>', '</s>', '<unk>', ',', '.', 'và', 'của', 'là', 'các', 'có', 'được', 'trong', 'cho', 'đã', 'với', 'một', 'không', 'người', ')', '(', 'những', '"', 'này', 'để', 'ở', 'khi', ':', 'về', 'năm', 'đến', '-', 'cũng', 'vào', 'trên', 'tại', 'nhiều', 'đó', 'sẽ', 'từ', 'ra', 'phải', 'như', 'ngày', 'lại', 'bị', 'ông', 'làm', 'hơn', 'việc', 'còn', 'nhưng', 'đang', 'sau', 'thì', 'biết', 'Việt_Nam', 'đi', 'nước', 'rất', 'mới', 'sự', 'có_thể', 'theo', 'mà', ';', 'chỉ', 'nhất', 'mình', 'nhà', 'tôi', 'trước', 'lên', 'con', 'vẫn', 'tới', '2', 'nên', 'tháng', 'Theo', 'đồng', 'cùng', 'hai', 'anh', 'cao', 'khác', 'họ', 'rằng', 'bạn', 'qua', 'vì', 'do', 'Trong', 'Mỹ', 'cả', '/', 'nói', 'đây', 'tỉnh', '1', 'số', 'lần', 'chưa', 'lớn', "'", 'xe', 'cô', '3', 'thấy', 'đường', 'cuộc', 'đưa', 'thực_hiện', 'triệu', '?', 'cần', 'tổ_chức', 'sử_dụng', 'hay', 'hàng', 'Hà_Nội', 'bằng', 'khiến', 'tiền', 'gần', 'Bộ', 'tuổi', 'đầu', 'tăng', 'thứ', 'thời_gian', 'đều', 'hoạt_động', 'giá', 'phát_triển', '...',
# ...

# %%
from transformers import BertModel

model = BertModel.from_pretrained('bert-base-multilingual-cased')
tensor_ind = torch.tensor(bertMultitokenizer.convert_tokens_to_ids(cleanText)).unsqueeze(0) 
print(model(tensor_ind))

# %%
from transformers import RobertaConfig
from transformers import RobertaModel

config = RobertaConfig.from_pretrained(
    "/content/drive/My Drive/EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/config.json"
)
phobert = RobertaModel.from_pretrained(
    "/content/drive/My Drive/EMPATHETICDIALOGUES/EmpatheticDialogues/PhoBert/PhoBERT_base_transformers/model.bin",
    config=config
)

# %%
#  print(phobert)
print(type(toId))
tensor_ind = torch.tensor(toId).unsqueeze(0) 

features = phobert(tensor_ind)
print(features)
